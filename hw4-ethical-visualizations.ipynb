# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('greenhouse-emissions.csv')

# %%
df.head()
# Out:
#    COU    Country  POL         Pollutant    VAR  \
# 0  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 1  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 2  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 3  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 4  AUS  Australia  GHG  Greenhouse gases  TOTAL
#
#                             Variable   YEA  Year   Unit Code  \
# 0  Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1  Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 2  Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 3  Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 4  Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
#
#                        Unit  PowerCode Code  PowerCode  Reference Period Code  \
# 0  Tonnes of CO2 equivalent               3  Thousands                    NaN
# 1  Tonnes of CO2 equivalent               3  Thousands                    NaN
# ...

# %%
df['Country']
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Chile', 'Estonia',
#        'Israel', 'Russia', 'Slovenia', 'Latvia', 'Lithuania',
#        'OECD - Total', 'OECD - Europe', 'Brazil',
#        "China (People's Republic of)", 'Colombia', 'Costa Rica', 'India',
#        'Indonesia', 'South Africa', 'Argentina',
#        'European Union (28 countries)'], dtype=object)

# %%
US = df[df['Country'] == 'United States']

# %%
US.head()
# Out:
#       COU        Country  POL         Pollutant    VAR  \
# 7432  USA  United States  GHG  Greenhouse gases  TOTAL
# 7433  USA  United States  GHG  Greenhouse gases  TOTAL
# 7434  USA  United States  GHG  Greenhouse gases  TOTAL
# 7435  USA  United States  GHG  Greenhouse gases  TOTAL
# 7436  USA  United States  GHG  Greenhouse gases  TOTAL
#
#                                Variable   YEA  Year   Unit Code  \
# 7432  Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 7433  Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 7434  Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 7435  Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 7436  Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
#
#                           Unit  PowerCode Code  PowerCode  \
# 7432  Tonnes of CO2 equivalent               3  Thousands
# 7433  Tonnes of CO2 equivalent               3  Thousands
# 7434  Tonnes of CO2 equivalent               3  Thousands
# ...

# %%
import matplotlib.pyplot as plt

# %%
US1 = df.loc[df['COU'] == 'USA']

# %%
US_total = US1.loc[US1['VAR'] == 'TOTAL']

# %%
US_total
# Out:
#        COU        Country      POL                         Pollutant    VAR  \
# 7432   USA  United States      GHG                  Greenhouse gases  TOTAL
# 7433   USA  United States      GHG                  Greenhouse gases  TOTAL
# 7434   USA  United States      GHG                  Greenhouse gases  TOTAL
# 7435   USA  United States      GHG                  Greenhouse gases  TOTAL
# 7436   USA  United States      GHG                  Greenhouse gases  TOTAL
# ...    ...            ...      ...                               ...    ...
# 32152  USA  United States  HFC_PFC  Unspecified mix of HFCs and PFCs  TOTAL
# 32153  USA  United States  HFC_PFC  Unspecified mix of HFCs and PFCs  TOTAL
# 32154  USA  United States  HFC_PFC  Unspecified mix of HFCs and PFCs  TOTAL
# 32155  USA  United States  HFC_PFC  Unspecified mix of HFCs and PFCs  TOTAL
# 32156  USA  United States  HFC_PFC  Unspecified mix of HFCs and PFCs  TOTAL
#
# ...

# %%
df['VAR'].unique()
# Out:
# array(['TOTAL', 'INDEX_1990', 'GHG_CAP', 'WAS', 'IND_PROC', 'ENER', 'AGR',
#        'OTH', 'GHG_GDP', 'ENER_IND', 'LULUCF', 'ENER_OSECT', 'ENER_OTH',
#        'ENER_FU', 'ENER_MANUF', 'ENER_TRANS', 'INDEX_2000', 'TOTAL_LULU',
#        'ENER_CO2', 'AFOLU', 'ENER_IND_P', 'ENER_OTH_P', 'AGR_P', 'ENER_P',
#        'ENER_MANUF_P', 'ENER_OSECT_P', 'WAS_P', 'IND_PROC_P',
#        'ENER_TRANS_P', 'ENER_FU_P', 'OTH_P', 'ENER_CO2_P'], dtype=object)

# %%
df['POL'].unique()
# Out:
# array(['GHG', 'CO2', 'CH4', 'N2O', 'HFC', 'PFC', 'SF6', 'NF3', 'HFC_PFC'],
#       dtype=object)

# %%
US1
# Out:
#        COU        Country  POL         Pollutant           VAR  \
# 7432   USA  United States  GHG  Greenhouse gases         TOTAL
# 7433   USA  United States  GHG  Greenhouse gases         TOTAL
# 7434   USA  United States  GHG  Greenhouse gases         TOTAL
# 7435   USA  United States  GHG  Greenhouse gases         TOTAL
# 7436   USA  United States  GHG  Greenhouse gases         TOTAL
# ...    ...            ...  ...               ...           ...
# 51298  USA  United States  GHG  Greenhouse gases  ENER_TRANS_P
# 51299  USA  United States  GHG  Greenhouse gases  ENER_TRANS_P
# 51300  USA  United States  GHG  Greenhouse gases  ENER_TRANS_P
# 51301  USA  United States  GHG  Greenhouse gases  ENER_TRANS_P
# 51302  USA  United States  GHG  Greenhouse gases  ENER_TRANS_P
#
#                                 Variable   YEA  Year   Unit Code  \
# 7432   Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 7433   Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
US2 = US1[['POL', 'Pollutant', 'Value']]
US2
# Out:
#        POL         Pollutant        Value
# 7432   GHG  Greenhouse gases  6437000.131
# 7433   GHG  Greenhouse gases  6373259.703
# 7434   GHG  Greenhouse gases  6480086.588
# 7435   GHG  Greenhouse gases  6596774.554
# 7436   GHG  Greenhouse gases  6685730.471
# ...    ...               ...          ...
# 51298  GHG  Greenhouse gases       25.145
# 51299  GHG  Greenhouse gases       25.875
# 51300  GHG  Greenhouse gases       27.096
# 51301  GHG  Greenhouse gases       27.569
# 51302  GHG  Greenhouse gases       27.283
#
# [1479 rows x 3 columns]

# %%
mass = pd.read_csv('mass-shootings.csv')
mass
# Out:
#                                       case                location       date  \
# 0                    San Jose VTA shooting    San Jose, California    5/26/21
# 1                 FedEx warehouse shooting   Indianapolis, Indiana    4/15/21
# 2           Orange office complex shooting      Orange, California    3/31/21
# 3             Boulder supermarket shooting       Boulder, Colorado    3/22/21
# 4         Atlanta massage parlor shootings        Atlanta, Georgia    3/16/21
# ..                                     ...                     ...        ...
# 119        Shopping centers spree killings       Palm Bay, Florida  4/23/1987
# 120  United States Postal Service shooting        Edmond, Oklahoma  8/20/1986
# 121         San Ysidro McDonald's massacre  San Ysidro, California  7/18/1984
# 122              Dallas nightclub shooting           Dallas, Texas  6/29/1984
# 123                  Welding shop shooting          Miami, Florida  8/20/1982
#
# ...

# %%
type(mass['date'][1])
# Out:
# str

# %%
mass['year'] = mass['date'].str[-2:]
mass
# Out:
#                                       case                location       date  \
# 0                    San Jose VTA shooting    San Jose, California    5/26/21
# 1                 FedEx warehouse shooting   Indianapolis, Indiana    4/15/21
# 2           Orange office complex shooting      Orange, California    3/31/21
# 3             Boulder supermarket shooting       Boulder, Colorado    3/22/21
# 4         Atlanta massage parlor shootings        Atlanta, Georgia    3/16/21
# ..                                     ...                     ...        ...
# 119        Shopping centers spree killings       Palm Bay, Florida  4/23/1987
# 120  United States Postal Service shooting        Edmond, Oklahoma  8/20/1986
# 121         San Ysidro McDonald's massacre  San Ysidro, California  7/18/1984
# 122              Dallas nightclub shooting           Dallas, Texas  6/29/1984
# 123                  Welding shop shooting          Miami, Florida  8/20/1982
#
# ...

# %%
fatality = mass[['fatalities','year']]
fatality
# Out:
#      fatalities year
# 0             9   21
# 1             8   21
# 2             4   21
# 3            10   21
# 4             8   21
# ..          ...  ...
# 119           6   87
# 120          15   86
# 121          22   84
# 122           6   84
# 123           8   82
#
# [124 rows x 2 columns]

# %%
fatal_sum =  fatality.groupby(['year']).sum()
fatal_sum
# Out:
#       fatalities
# year
# 00             7
# 01             5
# 03             7
# 04             5
# 05            17
# 06            21
# 07            53
# 08            17
# 09            39
# 10             9
# 11            19
# 12            71
# 13            35
# 14            18
# 15            46
# 16            71
# 17           117
# 18            80
# 19            73
# 20             9
# 21            39
# 82             8
# 84            28
# 86            15
# 87             6
# 88             7
# 89            15
# 90            10
# 91            35
# 92             9
# 93            23
# 94             5
# 95             6
# 96             6
# 97             9
# 98            14
# 99            42

# %%
fatal_sum.to_excel("output.xlsx")

# %%
fatal_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 00 to 99
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fatalities  37 non-null     int64
# dtypes: int64(1)
# memory usage: 592.0+ bytes

# %%
fatal_sum['year'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-76829ab4d718> in <module>
# ----> 1 fatal_sum['year'][0]
#
# NameError: name 'fatal_sum' is not defined

# %%
type(fatality['year'])
# Out:
# pandas.core.series.Series

# %%
int(fatality['year'][2])
# Out:
# 1921

# %%
i = 0
for y in fatality['year']:
    if int(y) < 21:
        fatality['year'][i] = '20'+y
    else:
        fatality['year'][i] = '19'+y
    i += 1
fatality
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      fatalities  year
# 0             9  1921
# 1             8  1921
# 2             4  1921
# 3            10  1921
# 4             8  1921
# ..          ...   ...
# 119           6  1987
# 120          15  1986
# 121          22  1984
# 122           6  1984
# 123           8  1982
#
# [124 rows x 2 columns]

# %%
fat = pd.read_csv('fat.csv')
fat
# Out:
#     year  fatalities
# 0   1982           8
# 1   1984          28
# 2   1986          15
# 3   1987           6
# 4   1988           7
# 5   1989          15
# 6   1990          10
# 7   1991          35
# 8   1992           9
# 9   1993          23
# 10  1994           5
# 11  1995           6
# 12  1996           6
# 13  1997           9
# 14  1998          14
# 15  1999          42
# 16  2000           7
# 17  2001           5
# 18  2003           7
# 19  2004           5
# 20  2005          17
# 21  2006          21
# 22  2007          53
# 23  2008          17
# 24  2009          39
# 25  2010           9
# 26  2011          19
# 27  2012          71
# 28  2013          35
# 29  2014          18
# 30  2015          46
# 31  2016          71
# 32  2017         117
# 33  2018          80
# 34  2019          73
# 35  2020           9
# 36  2021          39

# %%
plt.title('Fatalities and Injuries of U.S. Mass Shootings 1982-2019')
plt.plot(fat['year'],fat['fatalities'], label = 'Total fatalities')
plt.plot(inj['year'],inj['injured'], label = 'Total injuries')
plt.ylim([0,150])
plt.xlabel('Year')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %%
injured = mass[['injured','year']]
injured_sum = injured.groupby(['year']).sum()
injured_sum
# Out:
#       injured
# year
# 00          0
# 01          4
# 03          8
# 04          7
# 05          9
# 06          7
# 07         32
# 08         24
# 09         39
# 10          2
# 11         21
# 12         80
# 13         13
# 14         28
# 15         43
# 16         83
# 17        587
# 18         70
# 19        112
# 20          0
# 21          9
# 82          3
# 84         20
# 86          6
# 87         14
# 88          4
# 89         41
# 90          4
# 91         26
# 92         10
# 93         34
# 94         23
# 95          0
# 96          1
# 97          5
# 98         36
# 99         47

# %%
injured_sum.to_excel("inj.xlsx")
inj = pd.read_csv('inj.csv')
inj
# Out:
#     year  injured
# 0   1982        3
# 1   1984       20
# 2   1986        6
# 3   1987       14
# 4   1988        4
# 5   1989       41
# 6   1990        4
# 7   1991       26
# 8   1992       10
# 9   1993       34
# 10  1994       23
# 11  1995        0
# 12  1996        1
# 13  1997        5
# 14  1998       36
# 15  1999       47
# 16  2000        0
# 17  2001        4
# 18  2003        8
# 19  2004        7
# 20  2005        9
# 21  2006        7
# 22  2007       32
# 23  2008       24
# 24  2009       39
# 25  2010        2
# 26  2011       21
# 27  2012       80
# 28  2013       13
# 29  2014       28
# 30  2015       43
# 31  2016       83
# 32  2017      587
# 33  2018       70
# 34  2019      112
# 35  2020        0
# 36  2021        9

# %%
black1 = pd.read_csv('fat.csv')
black1
# Out:
#    year  fatalities  injuries
# 0  1984          28        20
# 1  1989          15        41
# 2  1991          35        26
# 3  1993          23        34
# 4  1999          42        47
# 5  2005          17         9
# 6  2008          17        24
# 7  2010           9         2
# 8  2020           9         0

# %%
plt.cla()
plt.title('Fatalities and Injuries of U.S. Mass Shootings 1982-2019')
plt.plot(black1['year'],black1['fatalities'], label = 'Total fatalities')
plt.plot(black1['year'],black1['injuries'], label = 'Total injuries')
plt.legend()
# plt.ylim([0,150])
plt.xlabel('Year')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')
